# %%
from keras.datasets import cifar10
import numpy as np
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
from tensorflow.keras.utils import to_categorical
from keras import regularizers 
from keras.callbacks import LearningRateScheduler

# %%
(train_x, train_y), (test_x, test_y) = cifar10.load_data()
train_x = train_x / 255.
test_x = test_x / 255.
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
train_x.shape, train_y.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1))

# %%
input_shape = train_x.shape[1:]
num_classes = 10
dropout_CNN = 0.25
weight_decay = 1e-4
learning_rate = 3e-2

num_epochs = 100
batch_size = 64

# %%
tr_y = to_categorical(train_y, num_classes)
te_y = to_categorical(test_y, num_classes)
tr_y.shape, te_y.shape
# Out:
# ((50000, 10), (10000, 10))

# %%
inputs = layers.Input(input_shape)
net = layers.Conv2D(32, (3,3), padding='SAME',kernel_regularizer=regularizers.l2(weight_decay))(inputs)
net = layers.Activation('relu')(net)
net = layers.Conv2D(32, (3,3), padding='SAME',kernel_regularizer=regularizers.l2(weight_decay))(inputs)
net = layers.Activation('relu')(net)
net = layers.Conv2D(32, (3,3), padding='SAME',kernel_regularizer=regularizers.l2(weight_decay))(inputs)
net = layers.Activation('relu')(net)
net = layers.MaxPooling2D(pool_size=(2, 2))(inputs)
net = layers.Dropout(dropout_CNN)(net)

net = layers.Flatten()(net)
net = layers.Dense(512)(net)
net = layers.Activation('relu')(net)
net = layers.Dropout(0.5)(net)
net = layers.Dense(num_classes)(net)
net = layers.Activation('softmax')(net)

model = tf.keras.Model(inputs=inputs, outputs=net)

# %%
import functools
top1_acc = functools.partial(tf.keras.metrics.top_k_categorical_accuracy, k=1)
top1_acc.__name__ = 'top1_acc'
top5_acc = functools.partial(tf.keras.metrics.top_k_categorical_accuracy, k=5)
top5_acc.__name__ = 'top5_acc'
model.compile(optimizer=tf.keras.optimizers.Adam(lr=learning_rate), 
              loss='categorical_crossentropy', 
              metrics=['accuracy', top1_acc, top5_acc])

# %%
model.fit(train_x, tr_y, batch_size=batch_size,
          shuffle=True, epochs=num_epochs)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 7s 9ms/step - loss: 2.3059 - accuracy: 0.0990 - top1_acc: 0.0990 - top5_acc: 0.4994
# Epoch 2/100
# 782/782 [==============================] - 6s 8ms/step - loss: 2.3115 - accuracy: 0.0990 - top1_acc: 0.0990 - top5_acc: 0.5019
# Epoch 3/100
# 782/782 [==============================] - 6s 8ms/step - loss: 2.3055 - accuracy: 0.1006 - top1_acc: 0.1006 - top5_acc: 0.4976
# Epoch 4/100
# 782/782 [==============================] - 6s 8ms/step - loss: 2.3055 - accuracy: 0.0992 - top1_acc: 0.0992 - top5_acc: 0.4955
# Epoch 5/100
# 782/782 [==============================] - 6s 8ms/step - loss: 2.3150 - accuracy: 0.1000 - top1_acc: 0.1000 - top5_acc: 0.4977
# Epoch 6/100
# 782/782 [==============================] - 6s 8ms/step - loss: 2.3060 - accuracy: 0.0989 - top1_acc: 0.0989 - top5_acc: 0.4978
# Epoch 7/100
# 782/782 [==============================] - 6s 8ms/step - loss: 2.3053 - accuracy: 0.0985 - top1_acc: 0.0985 - top5_acc: 0.5002
# Epoch 8/100
# 782/782 [==============================] - 6s 8ms/step - loss: 2.3056 - accuracy: 0.1002 - top1_acc: 0.1002 - top5_acc: 0.4974
# Epoch 9/100
# 782/782 [==============================] - 6s 8ms/step - loss: 2.3098 - accuracy: 0.1009 - top1_acc: 0.1009 - top5_acc: 0.5004
# Epoch 10/100
# 162/782 [=====>........................] - ETA: 4s - loss: 2.3055 - accuracy: 0.1009 - top1_acc: 0.1009 - top5_acc: 0.5071
